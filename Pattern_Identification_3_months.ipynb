# %% [markdown]
# <a href="https://colab.research.google.com/github/y-patankar/StockMarket/blob/main/Pattern_Identification_3_months.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('COST (1).csv')

# Convert the Date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Filter the DataFrame to include only rows with dates after 05/01/2024
filtered_df = df[df['Date'] >= '2024-05-01']

# Display the filtered DataFrame

filtered_df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971  721.193237
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002  731.398743
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024  742.842468
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012  755.374634
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998  770.213501
# ..         ...         ...         ...         ...         ...         ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976  817.599976
# 249 2024-07-29  822.559998  823.739990  814.090027  815.559998  815.559998
# 250 2024-07-30  818.000000  822.000000  803.280029  810.030029  810.030029
# 251 2024-07-31  820.419983  825.479980  811.270020  822.000000  822.000000
# 252 2024-08-01  818.559998  824.169983  809.710022  816.890015  816.890015
#
#       Volume
# 189  1609100
# 190  1826900
# 191  2323300
# ...

# %%
df= filtered_df[['Date', 'Open', 'High', 'Low', 'Close']]
df
# Out:
#           Date        Open        High         Low       Close
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998
# ..         ...         ...         ...         ...         ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976
# 249 2024-07-29  822.559998  823.739990  814.090027  815.559998
# 250 2024-07-30  818.000000  822.000000  803.280029  810.030029
# 251 2024-07-31  820.419983  825.479980  811.270020  822.000000
# 252 2024-08-01  818.559998  824.169983  809.710022  816.890015
#
# [64 rows x 5 columns]

# %%
df['Body'] = abs(df['Close'] - df['Open'])
df['CandleSize'] = df['High'] - df['Low']

# Identify bullish green candlestick patterns
df['BullishGreen'] = (df['Close'] > df['Open']) & (df['Body'] >= 0.5 * df['CandleSize'])

# Display the DataFrame with the new column
df
# Out:
# <ipython-input-13-c1a40922fdcd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Body'] = abs(df['Close'] - df['Open'])
#           Date        Open        High         Low       Close       Body  \
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971   0.050049
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002   7.690002
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024   9.619995
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012   6.859985
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998  12.619996
# ..         ...         ...         ...         ...         ...        ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976   0.400024
# ...

# %%
df['Body'] = abs(df['Close'] - df['Open'])
df['CandleSize'] = df['High'] - df['Low']

# Identify bullish green candlestick patterns
df['BearRead'] = (df['Close'] < df['Open']) & (df['Body'] >= 0.5 * df['CandleSize'])

# Display the DataFrame with the new column
df
# Out:
#           Date        Open        High         Low       Close       Body  \
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971   0.050049
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002   7.690002
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024   9.619995
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012   6.859985
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998  12.619996
# ..         ...         ...         ...         ...         ...        ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976   0.400024
# 249 2024-07-29  822.559998  823.739990  814.090027  815.559998   7.000000
# 250 2024-07-30  818.000000  822.000000  803.280029  810.030029   7.969971
# 251 2024-07-31  820.419983  825.479980  811.270020  822.000000   1.580017
# 252 2024-08-01  818.559998  824.169983  809.710022  816.890015   1.669983
#
#      CandleSize  BullishGreen  BearRead
# ...

# %%
max_body_size = 0.0004
min_candle_size = 0.01

# Load the stock price data from CSV
# df = pd.read_csv('COST (1).csv')

# Calculate the necessary conditions
df['BodySize'] = abs(df['Open'] - df['Close'])
df['CandleSize'] = df['High'] - df['Low']

# Identify Doji pattern
df['Doji'] = ((df['BodySize'] < df['Close'] * max_body_size) &
              (df['CandleSize'] > df['Close'] * min_candle_size))

# Filter only the Doji rows
df
# Out:
#           Date        Open        High         Low       Close       Body  \
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971   0.050049
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002   7.690002
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024   9.619995
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012   6.859985
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998  12.619996
# ..         ...         ...         ...         ...         ...        ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976   0.400024
# 249 2024-07-29  822.559998  823.739990  814.090027  815.559998   7.000000
# 250 2024-07-30  818.000000  822.000000  803.280029  810.030029   7.969971
# 251 2024-07-31  820.419983  825.479980  811.270020  822.000000   1.580017
# 252 2024-08-01  818.559998  824.169983  809.710022  816.890015   1.669983
#
#      CandleSize  BullishGreen  BearRead   BodySize   Doji
# ...

# %%
df['UpperShadow'] = df['High'] - df[['Open', 'Close']].max(axis=1)
df['LowerShadow'] = df[['Open', 'Close']].min(axis=1) - df['Low']

# Identify spinning top candlestick patterns
df['SpinningTop'] = ((~df['Doji']) & df['Body'] <= 0.20 * df['CandleSize']) & \
                    (df['UpperShadow'] >= 0.25 * df['CandleSize']) & \
                    (df['LowerShadow'] >= 0.25* df['CandleSize'])

# Display the DataFrame with the new column
df
# Out:
#           Date        Open        High         Low       Close       Body  \
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971   0.050049
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002   7.690002
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024   9.619995
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012   6.859985
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998  12.619996
# ..         ...         ...         ...         ...         ...        ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976   0.400024
# 249 2024-07-29  822.559998  823.739990  814.090027  815.559998   7.000000
# 250 2024-07-30  818.000000  822.000000  803.280029  810.030029   7.969971
# 251 2024-07-31  820.419983  825.479980  811.270020  822.000000   1.580017
# 252 2024-08-01  818.559998  824.169983  809.710022  816.890015   1.669983
#
#      CandleSize  BullishGreen  BearRead   BodySize   Doji  UpperShadow  \
# ...

# %%
df['Body'] = abs(df['Close'] - df['Open'])
df['CandleSize'] = df['High'] - df['Low']

# Calculate the lower and upper shadows
df['LowerTail'] = df[['Open', 'Close']].min(axis=1) - df['Low']
df['UpperTail'] = df['High'] - df[['Open', 'Close']].max(axis=1)

# Identify Hammer candlestick patterns
df['Hammer'] = (
    (df['LowerTail'] >= 2 * df['Body']) &        # Lower tail is at least twice the body
    (df['UpperTail'] <= 0.3 * df['CandleSize']) &  # Upper tail is relatively small
    (df['Body'] <= 0.3 * df['CandleSize'])       # Body is relatively small
)

# Display the DataFrame with the new column
df
# Out:
#           Date        Open        High         Low       Close       Body  \
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971   0.050049
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002   7.690002
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024   9.619995
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012   6.859985
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998  12.619996
# ..         ...         ...         ...         ...         ...        ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976   0.400024
# 249 2024-07-29  822.559998  823.739990  814.090027  815.559998   7.000000
# 250 2024-07-30  818.000000  822.000000  803.280029  810.030029   7.969971
# 251 2024-07-31  820.419983  825.479980  811.270020  822.000000   1.580017
# 252 2024-08-01  818.559998  824.169983  809.710022  816.890015   1.669983
#
#      CandleSize  BullishGreen  BearRead   BodySize   Doji  UpperShadow  \
# ...

# %%
df[['Date','Hammer']]
# Out:
#           Date  Hammer
# 189 2024-05-01   False
# 190 2024-05-02   False
# 191 2024-05-03   False
# 192 2024-05-06   False
# 193 2024-05-07   False
# ..         ...     ...
# 248 2024-07-26   False
# 249 2024-07-29   False
# 250 2024-07-30   False
# 251 2024-07-31    True
# 252 2024-08-01   False
#
# [64 rows x 2 columns]

# %%
df['Body'] = abs(df['Close'] - df['Open'])
df['CandleSize'] = df['High'] - df['Low']

# Calculate the lower and upper shadows
df['LowerTail'] = df[['Open', 'Close']].min(axis=1) - df['Low']
df['UpperTail'] = df['High'] - df[['Open', 'Close']].max(axis=1)

# Identify Inverted Hammer candlestick patterns
df['InvertedHammer'] = (
    (df['LowerTail'] <= 0.3 * df['CandleSize']) &  # Lower tail is very small
    (df['UpperTail'] >= 2 * df['Body']) &        # Upper tail is at least twice the body
    (df['Body'] <= 0.3 * df['CandleSize'])       # Body is relatively small
)

# Display the DataFrame with the new column
print(df)
# Out:
#           Date        Open        High         Low       Close       Body  \
# 189 2024-05-01  722.270020  729.859985  715.320007  722.219971   0.050049
# 190 2024-05-02  724.750000  734.400024  720.630005  732.440002   7.690002
# 191 2024-05-03  734.280029  747.489990  733.349976  743.900024   9.619995
# 192 2024-05-06  749.590027  756.940002  746.479980  756.450012   6.859985
# 193 2024-05-07  758.690002  772.239990  755.570007  771.309998  12.619996
# ..         ...         ...         ...         ...         ...        ...
# 248 2024-07-26  818.000000  822.280029  809.010010  817.599976   0.400024
# 249 2024-07-29  822.559998  823.739990  814.090027  815.559998   7.000000
# 250 2024-07-30  818.000000  822.000000  803.280029  810.030029   7.969971
# 251 2024-07-31  820.419983  825.479980  811.270020  822.000000   1.580017
# 252 2024-08-01  818.559998  824.169983  809.710022  816.890015   1.669983
#
#      CandleSize  BullishGreen  BearRead   BodySize   Doji  UpperShadow  \
# ...

# %%
df[['Date','InvertedHammer']]
# Out:
#           Date  InvertedHammer
# 189 2024-05-01           False
# 190 2024-05-02           False
# 191 2024-05-03           False
# 192 2024-05-06           False
# 193 2024-05-07           False
# ..         ...             ...
# 248 2024-07-26           False
# 249 2024-07-29           False
# 250 2024-07-30           False
# 251 2024-07-31           False
# 252 2024-08-01           False
#
# [64 rows x 2 columns]

# %%
df[['Date','BullishGreen','BearRead','Doji','SpinningTop','Hammer','InvertedHammer']]
# Out:
#           Date  BullishGreen  BearRead   Doji  SpinningTop  Hammer  \
# 189 2024-05-01         False     False   True         True   False
# 190 2024-05-02          True     False  False        False   False
# 191 2024-05-03          True     False  False        False   False
# 192 2024-05-06          True     False  False        False   False
# 193 2024-05-07          True     False  False        False   False
# ..         ...           ...       ...    ...          ...     ...
# 248 2024-07-26         False     False  False         True   False
# 249 2024-07-29         False      True  False        False   False
# 250 2024-07-30         False     False  False        False   False
# 251 2024-07-31         False     False  False        False    True
# 252 2024-08-01         False     False  False         True   False
#
#      InvertedHammer
# 189           False
# 190           False
# 191           False
# 192           False
# 193           False
# ..              ...
# ...
